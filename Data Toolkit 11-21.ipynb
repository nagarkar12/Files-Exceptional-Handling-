# %%
import numpy as np
import pandas as pd

# %%
#Q11. Create two different Series, each of length 50, with the following criteria:
#a) The first Series should contain random numbers ranging from 10 to 50
df1 = pd.Series(np.random.randint(low = 10, size= 50, high=51))
df1
# Out:
# 0     47
# 1     12
# 2     50
# 3     27
# 4     13
# 5     14
# 6     48
# 7     13
# 8     37
# 9     43
# 10    29
# 11    37
# 12    26
# 13    40
# 14    42
# 15    41
# 16    26
# 17    20
# 18    18
# 19    49
# 20    40
# 21    40
# 22    49
# 23    16
# 24    34
# 25    40
# 26    21
# 27    40
# 28    16
# 29    17
# 30    38
# 31    22
# 32    29
# 33    45
# 34    48
# 35    26
# 36    43
# 37    47
# 38    24
# 39    16
# 40    18
# 41    13
# 42    40
# 43    37
# 44    41
# 45    23
# 46    16
# 47    35
# 48    50
# 49    31
# dtype: int64

# %%
#11. b) The second Series should contain random numbers ranging from 100 to 1000
df2 = pd.Series(np.random.randint(low = 100, size= 50, high=1001))
df2
# Out:
# 0     596
# 1     624
# 2     270
# 3     657
# 4     537
# 5     547
# 6     740
# 7     138
# 8     450
# 9     111
# 10    989
# 11    830
# 12    298
# 13    114
# 14    136
# 15    728
# 16    801
# 17    823
# 18    800
# 19    927
# 20    890
# 21    712
# 22    680
# 23    354
# 24    944
# 25    184
# 26    261
# 27    149
# 28    328
# 29    314
# 30    595
# 31    662
# 32    281
# 33    442
# 34    323
# 35    228
# 36    815
# 37    812
# 38    748
# 39    746
# 40    986
# 41    187
# 42    662
# 43    811
# 44    249
# 45    678
# 46    305
# 47    667
# 48    991
# 49    267
# dtype: int64

# %%
#11. c) Create a DataFrame by joining these Series by column, and, change the names of the columns to coll, 'col2, etc.
df = pd.DataFrame({'col1':df1, 'col2':df2})
df
# Out:
#     col1  col2
# 0     47   596
# 1     12   624
# 2     50   270
# 3     27   657
# 4     13   537
# 5     14   547
# 6     48   740
# 7     13   138
# 8     37   450
# 9     43   111
# 10    29   989
# 11    37   830
# 12    26   298
# 13    40   114
# 14    42   136
# 15    41   728
# 16    26   801
# 17    20   823
# 18    18   800
# 19    49   927
# 20    40   890
# 21    40   712
# 22    49   680
# 23    16   354
# 24    34   944
# 25    40   184
# 26    21   261
# 27    40   149
# 28    16   328
# 29    17   314
# 30    38   595
# 31    22   662
# 32    29   281
# 33    45   442
# 34    48   323
# 35    26   228
# 36    43   815
# 37    47   812
# 38    24   748
# 39    16   746
# 40    18   986
# 41    13   187
# 42    40   662
# 43    37   811
# 44    41   249
# 45    23   678
# 46    16   305
# 47    35   667
# 48    50   991
# 49    31   267

# %%
#Q12. perform the following operations using people data set:
#a) Delete the 'Email', 'Phone', and 'Date of birth columns from the dataset.
df  = pd.read_csv("People Data.csv")
del1 = df.drop(['Email', 'Phone', 'Date of birth'], axis=1)

# %%
#12. b) Delete the rows containing any missing values.
del2= df.dropna()

# %%
#12. d) Print the final output also
print(del1)
print(del2)
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                            Job Title  Salary
# 0                  Probation officer   90000
# 1                             Dancer   80000
# 2                               Copy   50000
# 3           Counselling psychologist   65000
# 4                Biomedical engineer  100000
# ...

# %%
#Q13. Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the following tasks using Matplotlib and NumPy:
#a) Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x,y, color='r', marker='o')

# %%
#Q12. b) Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.
#12. f) Display a legend for the scatter pot, the horizontal line, and the vertical line.
plt.scatter(x, y)

plt.axhline(y=0.5, color='r', linestyle='--', label='y = 0.5')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()

plt.show()

# %%
#12. Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.
#12. f) Display a legend for the scatter pot, the horizontal line, and the vertical line.

plt.scatter(x, y)

plt.axvline(x=0.5, color='g', linestyle='--', label='x = 0.5')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()

plt.show()

# %%
#Q12. d) Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'.
#e) Set the title of the lot as 'Advanced Scatter Plot of Random Values'
plt.scatter(x,y, color='r', marker='o')

plt.xlabel('x-axis')
plt.ylabel('y-axsi')
plt.title("Advanced Scatter Plot of Random Values")
plt.show()

# %%
#Q14. Create a time-series dataset in a Pandas DataFrame with columns: "Date', 'Temperature", "Humidity' and Perform the following tasks using Matplotlib:
#a) Plot the 'Temperature and Humidity on the same plot with different y-axes (left y-axis for 'Temperature and right y-axis for Humidity').
#b) Label the x-axis as Date.
#c) Set the title of the plot as Temperature and Humidity Over Time'.]

dates = pd.date_range(start='2023-01-01', end='2023-12-31')
temperature = np.random.randint(20, 40, size=len(dates))
humidity = np.random.randint(40, 80, size=len(dates))

data = {'Date': dates, 'Temperature': temperature, 'Humidity': humidity}
df = pd.DataFrame(data)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(df['Date'], df['Temperature'], color='blue', label='Temperature')
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color='blue')

ax2.plot(df['Date'], df['Humidity'], color='red', label='Humidity')
ax2.set_ylabel('Humidity (%)', color='red')

plt.title('Temperature and Humidity Over Time')
plt.legend()

plt.tight_layout()
plt.show()

# %%
#Q15. Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following tasks using Matplotlib:
#a) Plot a histogram of the data with 30 bins.
#b) Overlay a line plot representing the normal distribution's probability density function (PDF).
#c) Label the x-axis as 'Value' and the y-axis as Frequency/Probability..
#d) Set the title of the plot as Histogram with PDF Overlay.

#16. Set the title of the plot as 'Histogram with PDF Overlay.
import scipy.stats as stats

data = np.random.normal(loc=5, scale=2, size=1000)

plt.hist(data, bins=30, density=True, alpha=0.6)

mu, std = stats.norm.fit(data)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)

p = stats.norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)

plt.title('Histogram with PDF Overlay')

plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

plt.show()

# %%
#17. Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot'.
import seaborn as sns

x = np.random.randn(1000)
y = np.random.randn(1000)

quadrants = np.where(x >= 0, (y >= 0) * 1 + (y < 0) * 2,
                     (y >= 0) * 3 + (y < 0) * 4)

sns.scatterplot(x=x, y=y, hue=quadrants, palette='viridis')

plt.legend(title='Quadrant', labels=['Quadrant 1', 'Quadrant 2', 'Quadrant 3', 'Quadrant 4'])

plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.title('Quadrant-wise Scatter Plot')

plt.show()

# %%
#Q18. With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'sine Wave Function'.
from bokeh.plotting import figure, show

x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

p = figure(title="Simple line example", x_axis_label='x', y_axis_label='y')

p.line(x, y, legend_label="Temp.", line_width=2)

show(p)

# %%
#Q19.Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their values, add hover tooltips to display exact values, label the axes, and set the title as 'Random Categorical Bar Chart'.
from bokeh.models import ColumnDataSource
from bokeh.palettes import Bright6
from bokeh.plotting import figure, show

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
counts = [5, 3, 4, 2, 4, 6]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts, color=Bright6))

p = figure(x_range=fruits, y_range=(0,9), height=350, title="Fruit Counts",
           toolbar_location=None, tools="")

p.vbar(x='fruits', top='counts', width=0.9, color='color', legend_field="fruits", source=source)

p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)

# %%
#Q20. Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as 'Simple Line Plot'.
import plotly.graph_objects as go

x = [1, 2, 3, 4, 5]
y = [2, 4, 5, 3, 6]

fig = go.Figure(data=go.Scatter(x=x, y=y))

fig.update_layout(title='Simple Line Plot', xaxis_title='X-axis', yaxis_title='Y-axis')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#21. Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set the title as 'Interactive Pie Chart.
import plotly.graph_objects as go

# Generate random data
labels = ['A', 'B', 'C', 'D', 'E']
values = [15, 25, 10, 30, 20]

# Create a pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=0.3)])

# Add labels and percentages
fig.update_traces(textinfo='label+percent')

# Set the title
fig.update_layout(title='Interactive Pie Chart')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
